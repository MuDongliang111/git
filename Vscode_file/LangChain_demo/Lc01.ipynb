# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 创建一个llm模块

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(

    model="gpt-5.4-mini",

    api_key="your-api-key-here" # type: ignore

)

# %%
result = llm.invoke("你好")

print(result)
print(result.content)
# Out:
# content='你好！有什么我可以帮你的吗？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 7, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Do0lwZUlJyD1YSV63cl8ew3S9STY2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea0a6-b32e-78f3-b455-2b1ae17f81b9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 12, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 你好！有什么我可以帮你的吗？

# %%
llm.invoke("你好")
# Out:
# AIMessage(content='你好！有什么我可以帮你的吗？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 7, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Do0lxqrvj2QXGulSnVNSwAcRFaLBb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ea0a6-b826-78c0-bdde-55536e7eaa51-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 12, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Message

# %% [markdown]
# ### 1.单次对话

# %%
from langchain_core.messages import HumanMessage

result = llm.invoke(
    [
        HumanMessage(content="你好")
    ]
)
print(result)
print(result.content)
# Out:
# content='你好！有什么我可以帮你的吗？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 7, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Do0mQKsy3TKEyvyCwgEh6Wwe2O4Jf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea0a7-275f-70b0-b986-6af8f8d36bd3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 12, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 你好！有什么我可以帮你的吗？

# %% [markdown]
# ### 2.多轮对话

# %%
from langchain_core.messages import (
    HumanMessage,
    AIMessage
)

messages = [
    HumanMessage(content="我叫张三"),
    AIMessage(content="你好张三"),
    HumanMessage(content="我叫什么")
]

result = llm.invoke(messages)

print(result.content)
# Out:
# 你叫张三。
